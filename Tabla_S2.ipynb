# %% [markdown]
# | Base de datos                   | Versión / Fecha                                              | URL                                                                                                                                | Descripción                                                                                                                                                                             | Referencia                        |
# | ------------------------------- | ------------------------------------------------------------ | ---------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------- |
# | Clustered NR (NCBI)             | **NCBI Clustered NR, descargada antes de diciembre de 2025** | [https://www.ncbi.nlm.nih.gov/refseq/about/nonredundantproteins/](https://www.ncbi.nlm.nih.gov/refseq/about/nonredundantproteins/) | Base de datos de proteínas agrupadas derivada de NCBI nr mediante clustering de secuencias similares. Utilizada para anotación por homología reduciendo redundancia en búsquedas BLAST. | NCBI Resource Coordinators (2018) |
# | Conserved Domain Database (CDD) | **v3.21 (2024)**                                             | [https://www.ncbi.nlm.nih.gov/cdd](https://www.ncbi.nlm.nih.gov/cdd)                                                               | Base de datos de dominios proteicos conservados que integra modelos de Pfam, COG, SMART, TIGRFAM y modelos curados por NCBI/CDD.                                                        | Lu et al., 2020                   |
# | Pfam                            | **v38.0**                                             | [https://www.ebi.ac.uk/interpro/](https://www.ebi.ac.uk/interpro/)                                                                 | Base de datos de familias proteicas y dominios basada en modelos ocultos de Markov (HMM), utilizada para la identificación de familias y regiones conservadas.                          | Mistry et al., 2021               |
# | PANTHER                         | **v19.0 **                                             | [https://www.pantherdb.org/](https://www.pantherdb.org/)                                                                           | Base de datos de familias proteicas y clasificación funcional basada en relaciones evolutivas.                                                                                          | Mi et al., 2025                   |
# | KOfam                           | **Descargada el 2025-05-13**                                 | [https://www.genome.jp/tools/kofamkoala/](https://www.genome.jp/tools/kofamkoala/)                                                 | Base de datos de perfiles HMM para asignación de ortólogos KEGG (KO) y anotación funcional metabólica.                                                                                  | Aramaki et al., 2020              |

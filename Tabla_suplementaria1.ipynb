# %% [markdown]
# | Herramienta | Versión | GitHub / Sitio web | Explicación | Referencia | Sección |
# |-------------|---------|--------------------|-------------|------------|----------|
# | MMseqs2 | v18d8ddc | https://github.com/soedinglab/MMseqs2 | Realiza búsquedas rápidas de homología y anotación funcional mediante similitud de secuencias. | Steinegger & Söding (2017) | 4.4.1 |
# | TransDecoder | v5.7.1 | https://github.com/TransDecoder/TransDecoder | Identifica marcos abiertos de lectura (ORFs) y predice secuencias codificantes de proteínas (CDSs) a partir de transcriptomas ensamblados. | Haas et al. (2013) | 4.4.1 |
# | InterProScan | v5.76-107.0 | https://github.com/ebi-pf-team/interproscan | Identifica dominios, familias proteicas y firmas funcionales para la anotación de proteínas predichas. | Jones et al. (2014) | 4.4.1 |
# | FastQC | v0.12.1 | https://www.bioinformatics.babraham.ac.uk/projects/fastqc/ | Evalúa la calidad de datos de secuenciación mediante métricas como calidad Phred, contenido GC, duplicación y presencia de adaptadores. | Andrews (2010) | 4.4.2 |
# | MultiQC | v1.35 | https://github.com/MultiQC/MultiQC | Integra los resultados de múltiples herramientas de control de calidad en un único informe. | Ewels et al. (2016) | 4.4.2 |
# | fastp | v0.23.4 | https://github.com/OpenGene/fastp | Realiza filtrado de lecturas, eliminación de adaptadores y control de calidad de datos de secuenciación. | Chen et al. (2018) | 4.4.2 |
# | Bowtie2 | v2.5.1 | https://github.com/BenLangmead/bowtie2 | Alinea lecturas de secuenciación contra una referencia utilizando un índice FM-index. | Langmead & Salzberg (2012) | 4.4.2 |
# | Salmon | v1.10.0 | https://combine-lab.github.io/salmon/ | Cuantifica la abundancia de transcritos mediante pseudoalineamiento para análisis de expresión diferencial. | Patro et al. (2017) | 4.4.3 |
# | DESeq2 | v1.44.0 | https://bioconductor.org/packages/release/bioc/html/DESeq2.html | Identifica genes diferencialmente expresados mediante modelos lineales generalizados basados en la distribución binomial negativa. | Love et al. (2014) | 4.4.4 |
# | KofamKOALA | v1.3.0 | https://github.com/takaram/kofam_scan | Asigna identificadores KO mediante perfiles ocultos de Markov (HMMs), permitiendo la reconstrucción de rutas metabólicas KEGG. | Aramaki et al. (2020) | 4.4.5 |
# | clusterProfiler | v4.16.0 | https://bioconductor.org/packages/release/bioc/html/clusterProfiler.html | Realiza análisis de enriquecimiento funcional de ontologías génicas y rutas metabólicas. | Wu et al. (2021) | 4.4.5 |
# | R | v4.5.1 | https://cran.r-project.org/ | Proporciona un entorno de programación para análisis estadístico, minería de datos y visualización gráfica. | Ihaka & Gentleman (1996) | 4.4.5 |
# | Pathview | v1.48.0 | https://bioconductor.org/packages/release/bioc/html/pathview.html | Integra resultados de expresión génica con rutas metabólicas KEGG para su visualización e interpretación. | Luo & Brouwer (2013) | 4.4.5 |
# | MAFFT | v7.505 | https://github.com/GSLBiotech/mafft | Genera alineamientos múltiples de secuencias mediante algoritmos progresivos e iterativos. | Katoh et al. (2002) | 4.4.6 |
# | Jalview | v2.11.4.0 | https://github.com/jalview/jalview | Permite visualizar, editar y analizar alineamientos múltiples de secuencias, evaluando conservación, variabilidad y características estructurales. | Waterhouse et al. (2009) | 4.4.6 |
